# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from ipywidgets import interact, widgets
import joblib  # For loading pickled models/data if needed

# %%
# Load clean dataset
df = pd.read_csv('/workspaces/uganda-budget-analysis/uganda_budget_cleaned.csv')
df_2122= pd.read_excel('/workspaces/uganda-budget-analysis/budget_datasets/budget_fy_21_22.xlsx')  # Or pd.read_pickle('clean_budget_data.pkl')
df.head()
# Out:
#   FinancialYear          Sector  Approved Budget
# 0    2015-06-01  Accountability     1.042134e+12
# 1    2015-06-01     Agriculture     5.134347e+11
# 2    2015-06-01       Education     2.346264e+12
# 3    2015-06-01          Energy     2.858441e+12
# 4    2015-06-01          Health     1.315735e+12

# %%
df_2122.head()
# Out:
#         Year SourceOfFunding  Category  SectorCode   SectorName  VoteCode  \
# 0  2021-2022         Arrears  Approved           1  Agriculture        10
# 1  2021-2022         Arrears  Approved           1  Agriculture        10
# 2  2021-2022         Arrears  Approved           1  Agriculture        10
# 3  2021-2022         Arrears  Approved           1  Agriculture       125
# 4  2021-2022         Arrears  Approved           1  Agriculture       142
#
#                                             VoteName  ProgramCode  \
# 0  Ministry of Agriculture, Animal Industry & Fis...            5
# 1  Ministry of Agriculture, Animal Industry & Fis...           49
# 2  Ministry of Agriculture, Animal Industry & Fis...           49
# 3  National Animal Genetic Res. Centre and Data Bank           56
# 4        National Agricultural Research Organisation           51
#
#                                        ProgrammeName  SubProgramCode  ...  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis: Funding Patterns
# # Here we explore historical sector allocations, noting PBB shifts around FY 2020/21.

# %%
# Code cell: Copied from eda.ipynb
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='FinancialYear', y='Approved Budget', hue='Sector')
plt.title('Historical Budget Trends by Sector')
plt.show()
